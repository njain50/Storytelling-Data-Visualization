# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
#load csv into gs->(gender stats)
gs = pd.read_csv("gender_statistics.csv")
#drop the column
gs.drop(['Series Code','2020 [YR2020]'], axis = 1, inplace = True)

#find a duplicate rows
duplicateDFrows = gs[gs.duplicated(['Country Name', 'Country Code', 'Series Name'])]
print(duplicateDFrows)

gsdf = gs.rename(columns = {'2018 [YR2018]' : '2018', '2019 [YR2019]' : '2019'}, inplace = False)

#remove null values
gsdf = gsdf.dropna()

# check rows where values are not available, set a flag TRUE/FALSE in another column 
gsdf['flag'] = (gsdf['2019'] == '..') & (gsdf['2019'] == '..')

#drop rows where there are no values
idx = gsdf[gsdf['flag'] == True].index
gsdf.drop(idx, inplace = True)


gsdf.drop('flag', axis = 1, inplace = True)
gsdf.info()

gsdf.to_csv(r'G20_Countries_Economic_Social_stats.csv')
# Out:
#       Country Name Country Code Series Name 2018 [YR2018] 2019 [YR2019]
# 13105          NaN          NaN         NaN           NaN           NaN
# 13106          NaN          NaN         NaN           NaN           NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3390 entries, 0 to 12964
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  3390 non-null   object
#  1   Country Code  3390 non-null   object
#  2   Series Name   3390 non-null   object
#  3   2018          3390 non-null   object
#  4   2019          3390 non-null   object
# dtypes: object(5)
# memory usage: 158.9+ KB

# %% [markdown]
# # Create dataset to hold economic data of G20 Countries

# %%
#create economic indicator list bucket
gdp_list_ = ['GDP (current US$)', 'GDP per capita (Current US$)']

# %%
#create dataframe out of population bucket
tempDF = pd.DataFrame(columns = gsdf.columns)
economicDF = []

for item in gdp_list_:
    tempDF = gsdf[gsdf['Series Name'] == item]
    economicDF.append(tempDF)
    #print(populationDF)

economicDF = pd.concat(economicDF)
economicDF.info()
economicDF.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 152 to 12635
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  42 non-null     object
#  1   Country Code  42 non-null     object
#  2   Series Name   42 non-null     object
#  3   2018          42 non-null     object
#  4   2019          42 non-null     object
# dtypes: object(5)
# memory usage: 2.0+ KB
# Country Name    42
# Country Code    42
# Series Name     42
# 2018            42
# 2019            42
# dtype: int64

# %%
#save dataframe to csv
economicDF.to_csv(r'G20_Countries_economic_data.csv')

# %% [markdown]
# # Create dataset to hold population data under age 5

# %%
#create population list bucket -
list_bucket =['Age population, age 0, female, interpolated',
       'Age population, age 0, male, interpolated',
       'Age population, age 01, female, interpolated',
       'Age population, age 01, male, interpolated',
       'Age population, age 02, female, interpolated',
       'Age population, age 02, male, interpolated',
       'Age population, age 03, female, interpolated',
       'Age population, age 03, male, interpolated',
       'Age population, age 04, female, interpolated',
       'Age population, age 04, male, interpolated',
       'Age population, age 05, female, interpolated',
       'Age population, age 05, male, interpolated']

dict_bucket ={'Age population, age 0, female, interpolated':(0,'Female'),
       'Age population, age 0, male, interpolated':(0,'Male'),
       'Age population, age 01, female, interpolated':(1,'Female'),
       'Age population, age 01, male, interpolated':(1,'Male'),
       'Age population, age 02, female, interpolated':(2,'Female'),
       'Age population, age 02, male, interpolated':(2,'Male'),
       'Age population, age 03, female, interpolated':(3,'Female'),
       'Age population, age 03, male, interpolated':(3,'Male'),
       'Age population, age 04, female, interpolated':(4,'Female'),
       'Age population, age 04, male, interpolated':(4,'Male'),
       'Age population, age 05, female, interpolated':(5,'Female'),
       'Age population, age 05, male, interpolated':(5,'Male')}

# %%
#create dataframe out of population bucket
tempDF = pd.DataFrame(columns = gsdf.columns)
populationDF = []

for item in list_bucket:
    tempDF = gsdf[gsdf['Series Name'] == item]
    populationDF.append(tempDF)
    #print(populationDF)

populationDF = pd.concat(populationDF)
populationDF.info()
populationDF.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 21 to 11888
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  240 non-null    object
#  1   Country Code  240 non-null    object
#  2   Series Name   240 non-null    object
#  3   2018          240 non-null    object
#  4   2019          240 non-null    object
# dtypes: object(5)
# memory usage: 11.2+ KB
# Country Name    240
# Country Code    240
# Series Name     240
# 2018            240
# 2019            240
# dtype: int64

# %%
#function to retun age and gender
def update_age_gender(str):
    for item in dict_bucket.items():      
        if(str == item[0]):
            return(item[1][0],item[1][1])

agecol = []
gendercol = []
for item in map(lambda x: update_age_gender(x), populationDF['Series Name']):
    #print(item[0])
    agecol.append(item[0])
    gendercol.append(item[1])

#add age and gender attribute
populationDF['Age'] = agecol
populationDF['Gender'] = gendercol

populationDF.head()
# Out:
#      Country Name Country Code                                  Series Name  \
# 21      Argentina          ARG  Age population, age 0, female, interpolated
# 645     Australia          AUS  Age population, age 0, female, interpolated
# 1269       Brazil          BRA  Age population, age 0, female, interpolated
# 1893       Canada          CAN  Age population, age 0, female, interpolated
# 2517        China          CHN  Age population, age 0, female, interpolated
#
#          2018     2019  Age  Gender
# 21     367796   365277    0  Female
# 645    159460   163020    0  Female
# 1269  1438921  1422845    0  Female
# 1893   188712   193067    0  Female
# 2517  7888935  7745542    0  Female

# %%
populationDF.to_csv(r'G20_population_age_under5.csv')

# %% [markdown]
# # Create dataset for employment information

# %%
# bucket two to hold employers & employment attributes    
list_bucket2 = ['Employers, female (% of female employment) (modeled ILO estimate)',
       'Employers, male (% of male employment) (modeled ILO estimate)',
       'Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
       'Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
       'Employment in industry, female (% of female employment) (modeled ILO estimate)',
       'Employment in industry, male (% of male employment) (modeled ILO estimate)',
       'Employment in services, female (% of female employment) (modeled ILO estimate)',
       'Employment in services, male (% of male employment) (modeled ILO estimate)']

dict_bucket2 = {'Employers, female (% of female employment) (modeled ILO estimate)':'Female',
       'Employers, male (% of male employment) (modeled ILO estimate)':'Male',
       'Employment in agriculture, female (% of female employment) (modeled ILO estimate)':'Female',
       'Employment in agriculture, male (% of male employment) (modeled ILO estimate)':'Male',
       'Employment in industry, female (% of female employment) (modeled ILO estimate)':'Female',
       'Employment in industry, male (% of male employment) (modeled ILO estimate)':'Male',
       'Employment in services, female (% of female employment) (modeled ILO estimate)':'Female',
       'Employment in services, male (% of male employment) (modeled ILO estimate)':'Male'}

# %%
#create dataframe out of employment bucket
tempDF = pd.DataFrame(columns = gsdf.columns)
employmentnDF = []

for item in list_bucket2:
    tempDF = gsdf[gsdf['Series Name'] == item]
    employmentnDF.append(tempDF)
    #print(populationDF)

employmentnDF = pd.concat(employmentnDF)
employmentnDF.info()
employmentnDF.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 95 to 12582
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  168 non-null    object
#  1   Country Code  168 non-null    object
#  2   Series Name   168 non-null    object
#  3   2018          168 non-null    object
#  4   2019          168 non-null    object
# dtypes: object(5)
# memory usage: 7.9+ KB
# (168, 5)

# %%
employmentnDF.head()
# Out:
#      Country Name Country Code  \
# 95      Argentina          ARG
# 719     Australia          AUS
# 1343       Brazil          BRA
# 1967       Canada          CAN
# 2591        China          CHN
#
#                                             Series Name              2018  \
# 95    Employers, female (% of female employment) (mo...   2.6159999370575
# 719   Employers, female (% of female employment) (mo...  3.83599996566772
# 1343  Employers, female (% of female employment) (mo...   3.3050000667572
# 1967  Employers, female (% of female employment) (mo...  2.70499992370605
# 2591  Employers, female (% of female employment) (mo...  0.72299998998642
#
#                    2019
# 95     2.60899996757507
# 719    3.78999996185303
# 1343    3.2720000743866
# 1967   2.67600011825562
# 2591  0.745000004768372

# %%
#function to retun age and gender
def employment(str):
    #print(str)
    for item in dict_bucket2.items():
        #print(item)
        if(str == item[0]):
            return(item[1])

gendercol = []
for item in map(lambda x: employment(x), employmentnDF['Series Name']):
    #print(item[0])
    gendercol.append(item)

#add age and gender attribute
employmentnDF['Gender'] = gendercol

employmentnDF['2018'] = employmentnDF['2018'].astype(float)
employmentnDF['2019'] = employmentnDF['2019'].astype(float)

employmentnDF.head(50)
# Out:
#              Country Name Country Code  \
# 95              Argentina          ARG
# 719             Australia          AUS
# 1343               Brazil          BRA
# 1967               Canada          CAN
# 2591                China          CHN
# 3215               France          FRA
# 3839              Germany          DEU
# 4463                India          IND
# 5087            Indonesia          IDN
# 5711                Italy          ITA
# 6335                Japan          JPN
# 6959               Mexico          MEX
# 7583          Korea, Rep.          KOR
# 8207   Russian Federation          RUS
# 8831         Saudi Arabia          SAU
# 9455            Singapore          SGP
# 10079        South Africa          ZAF
# 10703              Turkey          TUR
# 11327       United States          USA
# 11951      United Kingdom          GBR
# 12575      European Union          EUU
# 96              Argentina          ARG
# 720             Australia          AUS
# 1344               Brazil          BRA
# 1968               Canada          CAN
# 2592                China          CHN
# 3216               France          FRA
# 3840              Germany          DEU
# 4464                India          IND
# 5088            Indonesia          IDN
# 5712                Italy          ITA
# 6336                Japan          JPN
# 6960               Mexico          MEX
# 7584          Korea, Rep.          KOR
# 8208   Russian Federation          RUS
# 8832         Saudi Arabia          SAU
# 9456            Singapore          SGP
# 10080        South Africa          ZAF
# 10704              Turkey          TUR
# 11328       United States          USA
# 11952      United Kingdom          GBR
# 12576      European Union          EUU
# 97              Argentina          ARG
# 721             Australia          AUS
# 1345               Brazil          BRA
# 1969               Canada          CAN
# 2593                China          CHN
# 3217               France          FRA
# 3841              Germany          DEU
# 4465                India          IND
#
#                                              Series Name       2018  \
# 95     Employers, female (% of female employment) (mo...   2.616000
# 719    Employers, female (% of female employment) (mo...   3.836000
# 1343   Employers, female (% of female employment) (mo...   3.305000
# 1967   Employers, female (% of female employment) (mo...   2.705000
# 2591   Employers, female (% of female employment) (mo...   0.723000
# 3215   Employers, female (% of female employment) (mo...   2.164000
# 3839   Employers, female (% of female employment) (mo...   2.295000
# 4463   Employers, female (% of female employment) (mo...   0.518000
# 5087   Employers, female (% of female employment) (mo...   1.904000
# 5711   Employers, female (% of female employment) (mo...   3.531000
# 6335   Employers, female (% of female employment) (mo...   0.741000
# 6959   Employers, female (% of female employment) (mo...   2.576000
# 7583   Employers, female (% of female employment) (mo...   3.525000
# 8207   Employers, female (% of female employment) (mo...   0.946000
# 8831   Employers, female (% of female employment) (mo...   0.205000
# 9455   Employers, female (% of female employment) (mo...   2.570000
# 10079  Employers, female (% of female employment) (mo...   2.293000
# 10703  Employers, female (% of female employment) (mo...   1.250000
# 11327  Employers, female (% of female employment) (mo...   1.793000
# 11951  Employers, female (% of female employment) (mo...   1.241000
# 12575  Employers, female (% of female employment) (mo...   2.486198
# 96     Employers, male (% of male employment) (modele...   4.864000
# 720    Employers, male (% of male employment) (modele...   7.533000
# 1344   Employers, male (% of male employment) (modele...   6.002000
# 1968   Employers, male (% of male employment) (modele...   6.366000
# 2592   Employers, male (% of male employment) (modele...   1.833000
# 3216   Employers, male (% of male employment) (modele...   6.142000
# 3840   Employers, male (% of male employment) (modele...   5.947000
# 4464   Employers, male (% of male employment) (modele...   2.385000
# 5088   Employers, male (% of male employment) (modele...   4.650000
# 5712   Employers, male (% of male employment) (modele...   7.899000
# 6336   Employers, male (% of male employment) (modele...   2.852000
# 6960   Employers, male (% of male employment) (modele...   6.150000
# 7584   Employers, male (% of male employment) (modele...   7.602000
# 8208   Employers, male (% of male employment) (modele...   1.920000
# 8832   Employers, male (% of male employment) (modele...   2.112000
# 9456   Employers, male (% of male employment) (modele...   5.639000
# 10080  Employers, male (% of male employment) (modele...   7.565000
# 10704  Employers, male (% of male employment) (modele...   5.962000
# 11328  Employers, male (% of male employment) (modele...   2.956000
# 11952  Employers, male (% of male employment) (modele...   2.775000
# 12576  Employers, male (% of male employment) (modele...   5.866933
# 97     Employment in agriculture, female (% of female...   0.058000
# 721    Employment in agriculture, female (% of female...   1.675000
# 1345   Employment in agriculture, female (% of female...   4.140000
# 1969   Employment in agriculture, female (% of female...   0.939000
# 2593   Employment in agriculture, female (% of female...  23.278000
# 3217   Employment in agriculture, female (% of female...   1.394000
# 3841   Employment in agriculture, female (% of female...   0.847000
# 4465   Employment in agriculture, female (% of female...  55.528000
#
#             2019  Gender
# 95      2.609000  Female
# 719     3.790000  Female
# 1343    3.272000  Female
# 1967    2.676000  Female
# 2591    0.745000  Female
# 3215    2.157000  Female
# 3839    2.278000  Female
# 4463    0.524000  Female
# 5087    1.929000  Female
# 5711    3.524000  Female
# 6335    0.745000  Female
# 6959    2.568000  Female
# 7583    3.547000  Female
# 8207    0.944000  Female
# 8831    0.207000  Female
# 9455    2.586000  Female
# 10079   2.310000  Female
# 10703   1.254000  Female
# 11327   1.765000  Female
# 11951   1.240000  Female
# 12575   2.475670  Female
# 96      4.864000    Male
# 720     7.460000    Male
# 1344    5.938000    Male
# 1968    6.312000    Male
# 2592    1.860000    Male
# 3216    6.122000    Male
# 3840    5.916000    Male
# 4464    2.390000    Male
# 5088    4.674000    Male
# 5712    7.895000    Male
# 6336    2.817000    Male
# 6960    6.127000    Male
# 7584    7.495000    Male
# 8208    1.911000    Male
# 8832    2.117000    Male
# 9456    5.624000    Male
# 10080   7.568000    Male
# 10704   5.957000    Male
# 11328   2.909000    Male
# 11952   2.771000    Male
# 12576   5.849120    Male
# 97      0.049000  Female
# 721     1.631000  Female
# 1345    4.099000  Female
# 1969    0.905000  Female
# 2593   22.635000  Female
# 3217    1.356000  Female
# 3841    0.811000  Female
# 4465   54.539001  Female

# %%
employmentnDF.to_csv(r'G20Countries_employment_stats.csv')
